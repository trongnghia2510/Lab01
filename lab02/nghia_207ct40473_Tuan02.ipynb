# %% [markdown]
# PHẦN 1: Thống kê dữ liệu

# %%
import pandas as pd #Thư viện chính để xử lý và phân tích dữ liệu.
import numpy as np #Thư viện hỗ trợ tính toán số học.

#'matplotlib.pyplot' và 'seaborn': Thư viện vẽ biểu đồ.
import matplotlib.pyplot as plt
import seaborn as sns

#'scipy.stats' và 'statsmodels.api': Thư viện hỗ trợ phân tích thống kê.
import scipy.stats as stats
import statsmodels.api as sm

#'pd.read_csv("processed_dulieuxettuyendaihoc.csv", index_col = "STT")': Đọc dữ liệu từ tệp CSV có tên 
# "processed_dulieuxettuyendaihoc.csv" và sử dụng cột "STT" làm chỉ số của DataFrame.
df = pd.read_csv("processed_dulieuxettuyendaihoc.csv", index_col = "STT")

#'df': Biến chứa DataFrame được đọc từ tệp CSV.
print(df.head(10))
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.00  7.54  7.01
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  4.69  5.47  5.07
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.77  5.38  6.04
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  6.21  5.20  6.88
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...  6.50  6.36  6.99
# 6    9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  7.8  ...  7.96  8.54  7.38
# 7    2.8  3.9  5.5  6.9  5.0  7.3  4.6  5.2  4.4  6.7  ...  4.90  5.60  6.01
# 8    8.3  6.0  7.6  5.1  7.5  4.7  5.8  7.2  6.7  6.3  ...  6.80  6.87  7.03
# 9    6.5  6.3  7.6  6.0  5.5  7.1  6.3  5.0  7.3  6.8  ...  6.23  6.72  7.56
# 10   7.3  5.9  4.7  7.1  6.7  7.9  6.7  7.7  8.0  6.8  ...  6.80  7.25  7.03
#
#      XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# STT
# ...

# %% [markdown]
# 1. Hãy sắp xếp dữ liệu điểm DH1 theo thứ tự tăng dần

# %%
df.sort_values(by=['DH1'])
#df.sort_values(by=['DH1']): Sắp xếp các dòng của DataFrame 'df' theo giá trị của cột 'DH1'.
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 54   4.9  5.9  6.2  5.6  5.9  5.0  7.0  5.6  6.1  7.1  ...  5.69  6.26  6.02
# 44   6.6  7.2  5.9  6.9  7.6  8.1  7.3  6.7  6.3  6.9  ...  7.05  6.61  6.77
# 73   5.5  6.6  7.2  7.6  5.5  6.7  6.7  5.2  6.0  6.8  ...  6.20  5.88  6.22
# 6    9.3  7.6  7.9  8.6  7.0  7.3  7.7  7.9  9.6  7.8  ...  7.96  8.54  7.38
# 88   7.3  4.3  5.3  5.8  4.9  3.7  5.6  5.3  5.9  6.0  ...  5.44  5.78  6.48
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 85   8.4  7.4  6.0  7.8  6.3  7.2  8.5  6.0  9.3  7.0  ...  7.23  7.77  7.58
# 12   7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  7.1  ...  7.43  7.72  7.49
# 24   5.3  6.3  5.7  6.9  5.9  7.5  6.6  5.1  6.4  6.9  ...  6.05  6.32  6.71
# 25   2.4  4.1  3.6  5.5  5.9  5.6  4.9  4.2  3.3  5.7  ...  4.45  4.88  5.41
# ...

# %% [markdown]
# 2. Hãy sắp xếp dữ liệu điểm DH2 tăng dần theo nhóm giới tính

# %%
df.sort_values(by=['GT','DH1'])
#df.sort_values(by=['GT', 'DH1']): Sắp xếp các dòng của DataFrame 'df' theo giá trị của hai cột 'GT' và 'DH1'.
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM1  TBM2  TBM3  \
# STT                                                    ...
# 44   6.6  7.2  5.9  6.9  7.6  8.1  7.3  6.7  6.3  6.9  ...  7.05  6.61  6.77
# 84   5.9  5.7  7.1  6.7  6.5  8.0  8.1  4.3  7.4  7.1  ...  6.47  7.11  7.47
# 13   7.3  6.3  8.7  7.7  6.6  8.5  6.9  8.5  5.8  5.7  ...  7.44  6.82  7.46
# 46   6.9  5.3  7.1  5.7  7.0  8.4  6.2  6.4  5.4  4.8  ...  6.69  6.29  6.58
# 51   5.5  7.1  6.1  5.8  6.2  6.9  7.3  6.1  6.2  6.7  ...  6.27  6.35  7.18
# ..   ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...   ...
# 91   8.1  7.7  9.1  8.5  6.1  8.6  8.8  7.3  8.8  8.3  ...  7.84  8.27  8.29
# 85   8.4  7.4  6.0  7.8  6.3  7.2  8.5  6.0  9.3  7.0  ...  7.23  7.77  7.58
# 12   7.9  7.0  9.1  8.6  6.1  7.0  5.6  9.0  8.2  7.1  ...  7.43  7.72  7.49
# 24   5.3  6.3  5.7  6.9  5.9  7.5  6.6  5.1  6.4  6.9  ...  6.05  6.32  6.71
# ...

# %% [markdown]
# 3. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1,
# Q2 và Q3 của DH1 theo KT

# %%
def get_mean(scores): #'def get_mean(scores):': Đây là cách định nghĩa một hàm trong Python. Tên hàm là 'get_mean' và nó nhận một tham số đầu vào là 'scores'.
    return sum(scores)/len(scores)
#'sum(scores)': Hàm 'sum()' của Python được sử dụng để tính tổng tất cả các phần tử trong danh sách 'scores'.

# %%
result = df['DH1'].sum()
#'df['DH1'].sum()': Lấy cột DH1 từ DataFrame 'df' và tính tổng tất cả các giá trị trong cột này.
#'sum()': Đây là hàm của pandas để tính tổng các giá trị trong một Series (một cột của DataFrame).
#'result = df['DH1'].sum()': Kết quả tính tổng của cột DH1 được lưu vào biến 'result'.
print("\nDataFrame:\n")
#'print("\nDataFrame:\n")': In một dòng mới với tiêu đề "DataFrame:" để làm rõ phần kết quả.
print(result)
#'print(result)': In giá trị của biến result ra màn hình.
# Out:
# DataFrame:
#
# 374.0

# %%
def Q1(g):
    return np.percentile(g,25)
#'np.percentile(g, 25)': Sử dụng hàm 'percentile' của NumPy để tính giá trị tại vị trí 25% trong mảng 'g'.

# %%
def Q2(g):
    return np.percentile(g,50)
#'np.percentile(g, 50)': Sử dụng hàm 'percentile' của NumPy để tính giá trị tại vị trí 50% trong mảng 'g'.

# %%
def Q3(g):
    return np.percentile(g,75)
#'np.percentile(g, 75)': Sử dụng hàm 'percentile' của NumPy để tính giá trị tại vị trí 75% trong mảng 'g'.

# %%
def std(g):
    return np.std(g)
#'np.std(g)': Sử dụng hàm 'std' của NumPy để tính độ lệch chuẩn của mảng 'g'.

# %% [markdown]
# 4. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1,
# Q2 và Q3 của DH1 theo KT và KV

# %%
pd.pivot_table(data=df, index='KT', values='DH1', aggfunc=['sum','mean','median','min','max', std, Q1, Q2, Q3])
#'pd.pivot_table()': Hàm tạo bảng tổng hợp (pivot table) từ DataFrame.
#'data=df': Sử dụng DataFrame df.
#'index='KT'': Chỉ định cột KT làm chỉ mục của bảng tổng hợp.
#'values='DH1'': Chỉ định cột DH1 là cột được tính toán.
#'aggfunc=['sum', 'mean', 'median', 'min', 'max', 'std', Q1, Q2, Q3]': Danh sách các hàm tính toán cần thực hiện:
#'sum': Tổng.
#'mean': Giá trị trung bình.
#'median': Trung vị.
#'min': Giá trị nhỏ nhất.
#'max': Giá trị lớn nhất.
#'std': Độ lệch chuẩn.
#'Q1, Q2, Q3': Các hàm tùy chỉnh để tính các tứ phân vị (cần được định nghĩa trước).
# Out:
#        sum      mean median   min   max       std      Q1    Q2     Q3
#        DH1       DH1    DH1   DH1   DH1       DH1     DH1   DH1    DH1
# KT
# A   163.50  3.336735   3.25  1.00  6.50  1.261226  2.2500  3.25  4.250
# A1   17.50  2.916667   3.00  2.00  4.25  0.786165  2.1875  3.00  3.250
# B    29.50  3.277778   3.50  1.75  4.50  0.776785  3.2500  3.50  3.750
# C    79.25  5.660714   5.25  4.75  7.00  0.782665  5.0625  5.25  6.375
# D1   84.25  3.829545   3.75  1.25  6.75  1.338644  3.0000  3.75  4.875

# %% [markdown]
# 4. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1,
# Q2 và Q3 của DH1 theo KT và KV

# %%
pd.pivot_table(data=df, index=['KT', 'KV'], values='DH1', aggfunc=['sum','mean','median','min','max', std, Q1, Q2, Q3])
#'index=['KT', 'KV']': Sử dụng hai cột KT và KV làm chỉ mục của bảng tổng hợp. Điều này tạo ra một bảng tổng hợp có cấp bậc (multi-level index).
# Out:
#           sum      mean median   min   max       std      Q1     Q2      Q3
#           DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1     DH1
# KT KV
# A  1    93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250  4.2500
#    2    31.75  3.527778  3.500  2.00  6.25  1.346005  2.2500  3.500  4.2500
#    2NT  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500  4.1250
# A1 1     4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375  2.5625
#    2NT  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250  3.5000
# B  1    25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375  3.5625
#    2NT   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750  3.7500
# C  1    43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250  5.4375
#    2    11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750  6.1250
#    2NT  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000  6.8125
# ...

# %% [markdown]
# 5. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, std, Q1,
# Q2 và Q3 của DH1 theo KT, KV và DT

# %%
pd.pivot_table(data=df, index=['KT','KV','DT'], values='DH1', aggfunc=['sum','mean','median','min','max', std, Q1, Q2, Q3])
#'index=['KT', 'KV', 'DT']': Sử dụng ba cột KT, KV và DT làm chỉ mục của bảng tổng hợp. Điều này tạo ra một bảng tổng hợp có ba cấp bậc chỉ mục (multi-level index).
# Out:
#               sum      mean median   min   max       std      Q1     Q2  \
#               DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1
# KT KV  DT
# A  1   0.0  93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250
#    2   0.0  27.50  3.437500  3.000  2.00  6.25  1.401729  2.2500  3.000
#        6.0   4.25  4.250000  4.250  4.25  4.25  0.000000  4.2500  4.250
#    2NT 0.0  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500
# A1 1   0.0   4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375
#    2NT 0.0  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250
# B  1   0.0  25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375
#    2NT 0.0   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750
# C  1   0.0  43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250
#    2   0.0  11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750
#    2NT 0.0  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000
# ...

# %% [markdown]
# PHẦN 2: Trình bày dữ liệu

# %% [markdown]
# 1. Hãy trình bày dữ liệu biến: GT
# Gợi ý
# - Lập bảng tần số và tần suất
# - Vẽ biểu đồ tần số (cột), biểu đồ tần suất (tròn).

# %%
gt = df.groupby('GT')['GT'].agg('count')
#'df.groupby('GT')': Nhóm các dòng trong DataFrame df theo cột GT (Giới tính).
#'['GT']': Chọn cột GT để thực hiện các thao tác sau khi nhóm.
#'agg('count')': Áp dụng hàm count để đếm số lượng phần tử trong mỗi nhóm.

# %%
gt.plot.bar()#'plot.bar()': Đây là phương thức của đối tượng Series trong pandas để vẽ biểu đồ thanh (bar chart).
# Out:
# <Axes: xlabel='GT'>

# %%
gt.plot.pie() #'plot.pie()': Đây là phương thức của đối tượng Series trong pandas để vẽ biểu đồ tròn (pie chart).
# Out:
# <Axes: ylabel='GT'>

# %% [markdown]
# 2. Hãy trình bày dữ liệu lần lượt các biến: US_TBM1, US_TBM2 và US_TBM3

# %%
cau22 = pd.DataFrame(df, columns=['US_TBM1', 'US_TBM2', 'US_TBM3'])
#'pd.DataFrame(df, columns=['US_TBM1', 'US_TBM2', 'US_TBM3'])': Tạo một DataFrame mới 'cau22' từ DataFrame 'df',
#  chỉ bao gồm các cột có tên là 'US_TBM1', 'US_TBM2', và 'US_TBM3'.

# %%
cau22.describe()
#'describe()' sẽ tính và hiển thị các thống kê mô tả cơ bản của các cột số trong DataFrame (hoặc Series)
# Out:
#           US_TBM1     US_TBM2    US_TBM3
# count  100.000000  100.000000  100.00000
# mean     2.434480    2.559600    2.67176
# std      0.391203    0.377656    0.29981
# min      1.616000    1.768000    1.91600
# 25%      2.107000    2.223000    2.47300
# 50%      2.480000    2.588000    2.70600
# 75%      2.724000    2.893000    2.87400
# max      3.232000    3.416000    3.31600

# %% [markdown]
# 3. Hãy trình bày dữ liệu biến DT với các học sinh là nam

# %%
cau3 = df[df['GT'] == 'M']
cau3.groupby('DT')['DT'].agg('count')
#'cau3 = df[df['GT'] == 'Nam']': Tạo DataFrame 'cau3' từ DataFrame 'df' với các dòng mà giới tính ('GT') là 'Nam'.
#'.groupby('DT')': Nhóm các dòng của DataFrame 'cau3' theo giá trị của cột 'DT'.
#'['DT'].agg('count')': Áp dụng hàm đếm ('count') vào cột 'DT' sau khi nhóm các dòng. Kết quả là Series chứa số lượng các nhóm được đếm dựa trên cột 'DT'.
# Out:
# DT
# 0.0    50
# 1.0     1
# 6.0     1
# Name: DT, dtype: int64

# %% [markdown]
# 4. Hãy trình bày dữ liệu biến KV với các học sinh là nam thuộc dân tộc Kinh, có điểm thỏa
# mãn điều kiện (DH1 >= 5.0 và DH2 >= 4.0 và DH3 >= 4.0)

# %%
cau4 = df[(df['GT'] == 'M') & (df['DT'] == 1)]
cau4.groupby('DT')['DT'].agg('count')
#'cau4 = df[(df['GT'] == 'M') & (df['DT'] == 1)]': Lọc các dòng từ DataFrame df mà có giới tính ('GT') là 'M' (Nam) và có điểm thi ('DT') bằng 1.
# Out:
# DT
# 1.0    1
# Name: DT, dtype: int64

# %% [markdown]
# PHẦN 3: Trực quan hóa dữ liệu theo nhóm phân loại

# %% [markdown]
# 1. Trực quan dữ liệu học sinh nữ trên các nhóm XL1, XL2, XL3 dạng unstacked
# Gợi ý
# - Lọc dữ liệu giới tính là nữ
# - Oy: Chiều cao biểu đồ cột thể hiển số lượng học sinh theo xếp loại
# - Màu sắc thể hiện giá trị xếp loại: [Y, TB, K, G, XS]
# - Ox: thể hiện nhóm XL1, XL2 và XL3

# %%
cau1 = df[df['GT'] == 'F'].groupby(['XL1', 'XL2', 'XL3'])[['GT']].count()
#'df[df['GT'] == 'F']': Lọc các dòng trong DataFrame 'df' mà cột 'GT' có giá trị bằng 'F' (nữ).
#'.groupby(['XL1', 'XL2', 'XL3'])': Nhóm dữ liệu theo các cột 'XL1', 'XL2', và 'XL3'. Các giá trị trong các cột này sẽ được sử dụng để nhóm các dòng tương ứng.
#'[['GT']]': Chỉ ra rằng chúng ta quan tâm đến cột 'GT' sau khi đã nhóm.
#'.count()': Áp dụng hàm đếm để tính số lượng các giá trị trong mỗi nhóm.
#'cau1 = ...': Kết quả của phép tính được lưu vào biến 'cau1'.

# %%
cau1.unstack() #'unstack()' là một phương thức của đối tượng Series trong pandas.
# Out:
#           GT
# XL3        G     K   TB
# XL1 XL2
# G   G    1.0   NaN  NaN
# K   G    NaN   1.0  NaN
#     K    NaN  20.0  1.0
#     TB   NaN   2.0  NaN
# TB  K    NaN   8.0  1.0
#     TB   NaN   3.0  6.0
# Y   TB   NaN   1.0  3.0
#     Y    NaN   NaN  1.0

# %%
cau1.plot.bar() #'.plot.bar()': Là phương thức của pandas dùng để vẽ biểu đồ cột từ dữ liệu trong 'cau1'.
# Out:
# <Axes: xlabel='XL1,XL2,XL3'>

# %% [markdown]
# PHẦN 4: Trực quan hóa dữ liệu nâng cao

# %% [markdown]
# 1. Vẽ biểu đồ đường Simple cho biến T1

# %%
df.groupby('T1')['T1'].count().plot()
#'df.groupby('T1')': Đây là phương thức của pandas để nhóm các dòng trong DataFrame 'df' theo giá trị của cột 'T1'.
# '['T1']': Chỉ định cột 'T1' là cột mà chúng ta muốn đếm số lượng phần tử trong từng nhóm.
#'.count()': Là phương thức để đếm số lượng phần tử trong từng nhóm sau khi đã nhóm bởi 'T1'. 
#'.plot()': Phương thức này sử dụng để vẽ biểu đồ của kết quả đã nhóm và đếm được.
# Out:
# <Axes: xlabel='T1'>

# %% [markdown]
# 2. Hãy tạo biến phân loại (phanlopt1) cho môn toán (T1) như sau:
# a. Từ 0 đến dưới 5 = kém (ký hiệu ―k‖)
# b. Từ 5 đến dưới 7 = trung bình (ký hiệu ―tb‖)
# c. Từ 7 đến dưới 8 = khá (ký hiệu ―k‖)
# d. Từ 8 trở lên = giỏi (ký hiệu ―g‖)

# %%
df.loc[(df['T1'] < 5), 'phanlopt1'] = 'kem'
df.loc[(df['T1'] >= 5) & (df['T1'] < 7), 'phanlopt1'] = 'trungbinh'
df.loc[(df['T1'] >= 7) & (df['T1'] < 8), 'phanlopt1'] = 'kha'
df.loc[(df['T1'] >= 8), 'phanlopt1'] = 'gioi'

#'df['T1'] < 5': Điều kiện để xác định các dòng có giá trị của cột 'T1' nhỏ hơn 5.
#'df['T1'] >= 5) & (df['T1'] < 7)': Điều kiện để xác định các dòng có giá trị của cột 'T1' từ 5 đến dưới 7.
#'df['T1'] >= 7) & (df['T1'] < 8)': Điều kiện để xác định các dòng có giá trị của cột 'T1' từ 7 đến dưới 8.
#'df['T1'] >= 8': Điều kiện để xác định các dòng có giá trị của cột 'T1' lớn hơn hoặc bằng 8.

# %%
df.head(5) #'df.head(5)': Phương thức này của pandas được sử dụng để trích xuất số lượng dòng được chỉ định từ đầu DataFrame.
# Out:
#       T1   L1   H1   S1   V1   X1   D1   N1   T2   L2  ...  TBM2  TBM3  XL1  \
# STT                                                    ...
# 1    7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  8.9  ...  7.54  7.01    K
# 2    5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  5.4  ...  5.47  5.07    Y
# 3    5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  4.9  ...  5.38  6.04   TB
# 4    6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  6.2  ...  5.20  6.88   TB
# 5    6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  5.5  ...  6.36  6.99    K
#
#      XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT  phanlopt1
# STT
# 1      K    K    2.800    3.016    2.804   0.0        kha
# 2     TB   TB    1.876    2.188    2.028   0.0  trungbinh
# 3     TB   TB    2.308    2.152    2.416   1.0  trungbinh
# 4     TB    K    2.484    2.080    2.752   0.0  trungbinh
# 5     TB    K    2.600    2.544    2.796   0.0  trungbinh
#
# [5 rows x 66 columns]

# %% [markdown]
# 3. Vẽ biểu đồ đường Multiple Line cho biến T1 được phân loại bởi biến phanlopt1

# %%
dfphanlop1 = df.groupby(['T1', "phanlopt1"])[['T1', 'phanlopt1']].count()

#'df.groupby(['T1', "phanlopt1"])': Phương thức 'groupby()' chia DataFrame thành các nhóm dựa trên giá trị của các cột được chỉ định trong danh sách.
#'[['T1', 'phanlopt1']].count()': Chọn các cột 'T1' và 'phanlopt1' để tính số lượng dòng trong mỗi nhóm.
#'dfphanlop1 = ...': Kết quả của phép nhóm và tính toán được lưu vào DataFrame mới có tên là 'dfphanlop1'.

# %%
unstackphanlop1 = dfphanlop1.unstack() #'unstack()': Là phương thức của đối tượng DataFrame hoặc Series trong pandas.

# %%
unstackphanlop1.head(10)

#'unstack()': Phương thức 'unstack()' trong pandas được sử dụng để chuyển đổi một cấu trúc dữ liệu đa cấp thành dạng bảng dữ liệu.
#'head(10)': Phương thức 'head()' dùng để hiển thị một số lượng dòng đầu tiên của DataFrame, mặc định là 5 dòng nếu không có tham số nào được cung cấp.
# Out:
#             T1                    phanlopt1
# phanlopt1 gioi  kem kha trungbinh      gioi  kem kha trungbinh
# T1
# 2.4        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.5        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.6        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.7        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.8        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 3.0        NaN  2.0 NaN       NaN       NaN  2.0 NaN       NaN
# 3.4        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 3.6        NaN  2.0 NaN       NaN       NaN  2.0 NaN       NaN
# 3.7        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 3.9        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN

# %% [markdown]
# 4. Vẽ biểu đồ đường Multiple Line cho biến T1 được phân loại bởi biến phanlopt1

# %%
unstackphanlop1['phanlopt1'].plot(ylabel='count')

#'unstack()': Phương thức 'unstack()' trong pandas được sử dụng để chuyển đổi một cấu trúc dữ liệu đa cấp thành dạng bảng dữ liệu.
#'['phanlopt1']': Sau khi 'unstack', ta lấy cột phanlopt1 để vẽ biểu đồ. Đây là một cột trong DataFrame hoặc Series sau khi đã 'unstack'.
#'ylabel='count'': Thiết lập nhãn trục y của biểu đồ là 'count' (số lượng).
# Out:
# <Axes: xlabel='T1', ylabel='count'>

# %% [markdown]
# 5.  Vẽ biểu đồ Drop-line cho biến T1 được phân loại bởi biến phanlopt1

# %%
unstackphanlop1['phanlopt1'].plot.bar()
#'unstackphanlop1['phanlopt1']':Đây là cách truy cập vào một cột cụ thể trong DataFrame 'unstackphanlop1'. Cột này có tên là 'phanlopt1'
#.plot.bar()':Đây là phương thức của pandas DataFrame được sử dụng để vẽ biểu đồ cột (bar chart)
# Out:
# <Axes: xlabel='T1'>

# %% [markdown]
# PHẦN 5: Mô tả dữ liệu và khảo sát dạng phân phối

# %% [markdown]
# 1. Hãy mô tả và khảo sát phân phối cho biến T1
# Gợi ý
# - Mô tả độ tập trung và phân tán của dữ liệu T1
# - Vẽ biểu đồ Box-Plot và xác định các 10 đại lượng trong biểu đồ đó
# - Mô tả hình dáng lệch của phân phối T1 dựa vào các đại lượng hướng tâm
# - Vẽ biểu đồ Histogram biểu thị hình dáng phân phối
# - Mô tả các đặc trưng của phân phối, mức độ lệch và mức độ nhọn
# - Kiểm chứng phân phối chuẩn QQ-Plot
# - Nhận xét và đánh giá về phân phối của T1

# %%
plt.boxplot(df['T1'])
#'plt.boxplot(...)': Đây là hàm trong thư viện matplotlib.pyplot để vẽ biểu đồ boxplot.
#'df['T1']': Lấy dữ liệu từ cột 'T1' trong DataFrame 'df' để vẽ boxplot của cột này.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x232e8a7bbb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x232e8aa00d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x232e8a7b8e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x232e8aa0610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x232e8aa08b0>],
#  'means': []}

# %%
df['T1'].describe()
#'df['T1']': Chọn cột có tên là 'T1' từ DataFrame 'df'.
#.describe(): Là phương thức của pandas dùng để tạo ra một tóm tắt thống kê của dữ liệu trong cột đã chọn.
# Out:
# count    100.000000
# mean       5.946000
# std        1.608338
# min        2.400000
# 25%        5.000000
# 50%        5.850000
# 75%        7.200000
# max        9.300000
# Name: T1, dtype: float64

# %%
df['T1'].hist(bins = 20)
#'df['T1']': Trích xuất cột có tên là 'T1' từ DataFrame 'df'.
#.hist(bins=20): Phương thức 'hist()' của pandas được sử dụng để vẽ histogram của dữ liệu trong cột 'T1'.
# Out:
# <Axes: >

# %%
sm.qqplot(df['T1'],line = '45')
#'sm.qqplot()': Đây là hàm trong thư viện 'statsmodels.api' để vẽ đồ thị quantile-quantile (QQ plot).

# %% [markdown]
# Câu 2: Hãy mô tả và khảo sát phân phối cho biến T1 trên từng nhóm phân lớp (phanlopT1)

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(y='T1', x='phanlopt1', data=df)
plt.title('Box Plot of T1 grouped by phanlopt1')
plt.xlabel('phanlopt1')
plt.ylabel('T1')
plt.show()

#'plt.figure(figsize=(10, 6))':Tạo một figure mới với kích thước 10x6 inches để vẽ biểu đồ boxplot.
#'sns.boxplot(y='T1', x='phanlopt1', data=df)':'
# 'sns.boxplot(...)': Hàm từ thư viện Seaborn dùng để vẽ biểu đồ boxplot.
#'y='T1'': Đặt cột 'T1' làm dữ liệu cho trục y của boxplot.
#'x='phanlopt1'': Đặt cột 'phanlopt1' làm dữ liệu cho trục x và sắp xếp các boxplot theo giá trị của 'phanlopt1'.
#'data=df': Chỉ định DataFrame chứa dữ liệu.
#'plt.title('Biểu đồ Boxplot của T1 nhóm theo phân nhóm phanlopt1')':Đặt tiêu đề cho biểu đồ.
#'plt.xlabel('phanlopt1')' và 'plt.ylabel('T1')':Đặt nhãn cho trục 'x' là 'phanlopt1' và trục y là 'T1'.
#'plt.show()':Hiển thị biểu đồ boxplot lên màn hình.

# %%
sns.histplot(y = 'T1',x = 'phanlopt1', data = df)

#'sns.histplot()': Đây là hàm trong thư viện seaborn được sử dụng để vẽ biểu đồ histogram.
#'y='T1'' và 'x='phanlopt1'': Xác định các trục của biểu đồ histogram.
#'y='T1'': Đặt dữ liệu từ cột T1 lên trục y của biểu đồ.
#'x='phanlopt1'': Đặt dữ liệu từ cột phanlopt1 lên trục x của biểu đồ.
#'data=df': Chỉ định DataFrame từ đó dữ liệu được lấy ra để vẽ biểu đồ. Trong trường hợp này, DataFrame là df.
# Out:
# <Axes: xlabel='phanlopt1', ylabel='T1'>

# %% [markdown]
# 3. Hãy khảo sát tương quan giữa biến DH1 theo biến T1

# %%
DH1_T1 = df[['DH1','T1']]
#'df[['DH1','T1']]': Đây là cú pháp của pandas để lấy ra một phần của DataFrame gốc 'df'.

# %%
sns.pairplot(DH1_T1, kind = 'scatter') #'sns.pairplot(DH1_T1, kind='scatter')': Tạo biểu đồ pairplot từ DataFrame 'DH1_T1'. 
plt.show() #'plt.show()': Hiển thị biểu đồ được tạo ra bằng Seaborn và Matplotlib.

# %% [markdown]
# 4. Hãy khảo sát tương quan giữa biến DH1 theo biến T1 trên từng nhóm khu vực

# %%
DH1_T1_KV = df[['DH1','T1','KV']]
sns.FacetGrid(DH1_T1_KV,col = 'KV').map(plt.scatter,'DH1','T1')
#'df[['DH1', 'T1', 'KV']]': Dùng để lựa chọn các cột 'DH1', 'T1', 'KV' từ DataFrame 'df' và tạo thành một DataFrame mới 'DH1_T1_KV'
#'sns.FacetGrid(DH1_T1_KV, col='KV')': Tạo một FacetGrid từ 'DataFrame DH1_T1_KV', với các cột của lưới dựa trên giá trị của cột 'KV'
#'.map(plt.scatter, 'DH1', 'T1')': Áp dụng hàm 'plt.scatter' để vẽ biểu đồ phân tán cho mỗi phần của lưới 'FacetGrid'.

# %% [markdown]
# 5. Hãy khảo sát tương quan giữa các biến DH1, DH2, DH3

# %%
DH1_DH2_DH3 = df[['DH1','DH2','DH3']]
#'[['DH1','DH2','DH3']]': Đoạn này sử dụng cú pháp của pandas để chỉ định danh sách các cột mà bạn muốn lựa chọn từ DataFrame 'df'.
#'['DH1', 'DH2', 'DH3']': Là một list chứa tên các cột mà bạn muốn lấy ra. Trong trường hợp này là các cột 'DH1', 'DH2', và 'DH3'.

# %%
sns.pairplot(DH1_DH2_DH3, kind = 'scatter')
#'sns.pairplot(DH1_DH2_DH3, kind='scatter')' trong Python sử dụng thư viện seaborn (được import như 'sns') để tạo biểu đồ pairplot từ DataFrame 'DH1_DH2_DH3'
